# %%
#Finding issues with our data
#Using Pandas to get the data ready for modelling
#Building a model to assess our chances of surviving the Titanic

# %%
#Finding issues with our data
# a) find the missing data
# b) Multiple pieces of information in one column
# c) useless/noisy columns

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic_data = pd.read_csv(r"C:\Users\Opicha\Downloads\train.csv")

# %%
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic_data['Name'].sample(50)
# Out:
# 582                           Downton, Mr. William James
# 355                          Vanden Steen, Mr. Leo Peter
# 653                        O'Leary, Miss. Hanora "Norah"
# 759    Rothes, the Countess. of (Lucy Noel Martha Dye...
# 679                   Cardeza, Mr. Thomas Drake Martinez
# 646                                    Cor, Mr. Liudevit
# 793                             Hoyt, Mr. William Fisher
# 826                                         Lam, Mr. Len
# 507        Bradley, Mr. George ("George Arthur Brayton")
# 265                                    Reeves, Mr. David
# 665                                   Hickman, Mr. Lewis
# 110                       Porter, Mr. Walter Chamberlain
# 650                                    Mitkoff, Mr. Mito
# 297                         Allison, Miss. Helen Loraine
# 169                                        Ling, Mr. Lee
# 575                                 Patchett, Mr. George
# ...

# %%
titanic_data.Survived.sum()
# Out:
# 342

# %%
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_data.set_index('PassengerId')
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
sns.heatmap(titanic_data.corr(), cmap= "YlGnBu")
plt.show()
# Out:
# C:\Users\Opicha\AppData\Local\Temp\ipykernel_3676\2425842164.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(titanic_data.corr(), cmap= "YlGnBu")

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split = StratifiedShuffleSplit(n_splits = 1, test_size = 0.2)
for train_indices, test_indices in split.split(titanic_data, titanic_data[["Survived", "Pclass", "Sex"]]):
    strat_train_set = titanic_data.loc[train_indices]
    strat_test_set = titanic_data.loc[test_indices]

# %%
strat_test_set
# Out:
#      PassengerId  Survived  Pclass  \
# 248          249         1       1
# 306          307         1       1
# 116          117         0       3
# 235          236         0       3
# 613          614         0       3
# ..           ...       ...     ...
# 214          215         0       3
# 119          120         0       3
# 85            86         1       3
# 252          253         0       1
# 316          317         1       2
#
#                                                   Name     Sex   Age  SibSp  \
# 248                      Beckwith, Mr. Richard Leonard    male  37.0      1
# 306                            Fleming, Miss. Margaret  female   NaN      0
# 116                               Connors, Mr. Patrick    male  70.5      0
# 235                       Harknett, Miss. Alice Phoebe  female   NaN      0
# 613                                   Horgan, Mr. John    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
plt.subplot(1,2,1)
strat_train_set['Survived'].hist()
strat_test_set['Pclass'].hist()

plt.subplot(1,2,2)
strat_train_set['Survived'].hist()
strat_test_set['Pclass'].hist()

plt.show()

# %%
strat_train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 712 entries, 602 to 123
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  712 non-null    int64
#  1   Survived     712 non-null    int64
#  2   Pclass       712 non-null    int64
#  3   Name         712 non-null    object
#  4   Sex          712 non-null    object
#  5   Age          574 non-null    float64
#  6   SibSp        712 non-null    int64
#  7   Parch        712 non-null    int64
#  8   Ticket       712 non-null    object
#  9   Fare         712 non-null    float64
#  10  Cabin        163 non-null    object
#  11  Embarked     710 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 72.3+ KB

# %%
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.impute import SimpleImputer

class AgeImputer (BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self
def trasnform(self, X):
    imputer = SimpleImputer(strategy="mean")
    X['Age'] = imputer.fit_transform(X[['Age']])
    return X

# %%
from sklearn.preprocessing import OneHotEncoder

class FeatureEncoder(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        encoder = OneHotEncoder()
        matrix= encoder.fit_tranform(X[['Embarked']]).toarray()
        
        column_names = ["C", "S", "Q", "N"]
        
        for i in range (len(matrix.T)):
            X[column_names[i]] = matrix.T[i]
        matrix= encoder.fit_tranform(X[['Embarked']]).toarray()
            
        column_names = ["Female"], ["Male"]
        
        for i in range (len(matrix.T)):
            X[column_names[i]] = matrix.T[i]
        return X

# %%
class FeatureDropper (BaseEstimator, TransformerMixin):
    
    def fit (self, X, y=None):
        return self
    
    def transform(self, X):
        return X.drop(["Embarked", "Name", "Ticket", "Cabin", "Sex", "N"], axis=1, errors="ignore")

# %%
from sklearn.pipeline import Pipeline

pipeline= Pipeline([("ageimputer", AgeImputer()),
                    ("featureencoder", FeatureEncoder()),
                    ("featuredropper", FeatureDropper())])

# %%
strat_train_set
# Out:
#      PassengerId  Survived  Pclass  \
# 602          603         0       1
# 452          453         0       1
# 671          672         0       1
# 549          550         1       2
# 858          859         1       3
# ..           ...       ...     ...
# 472          473         1       2
# 816          817         0       3
# 709          710         1       3
# 583          584         0       1
# 123          124         1       2
#
#                                                   Name     Sex   Age  SibSp  \
# 602                          Harrington, Mr. Charles H    male   NaN      0
# 452                    Foreman, Mr. Benjamin Laventall    male  30.0      0
# 671                             Davidson, Mr. Thornton    male  31.0      1
# 549                     Davies, Master. John Morgan Jr    male   8.0      1
# 858              Baclini, Mrs. Solomon (Latifa Qurban)  female  24.0      0
# ..                                                 ...     ...   ...    ...
# ...
